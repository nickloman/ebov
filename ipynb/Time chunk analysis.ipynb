# %% [markdown]
# # Time chunk analysis
#
# In this notebook we examine how the variant detection algorithm works over different levels of coverage:

# %% [markdown]
# Start with sample 076533
# Experiment time stamp start is 1444937896

# %%
start_time = 1444937896
for n in xrange(10, 60, 10):
    print n, start_time + (n * 60)
for n in xrange(60, 120, 20):
    print n, start_time + (n * 60)
# Out:
# 10 1444938496
# 20 1444939096
# 30 1444939696
# 40 1444940296
# 50 1444940896
# 60 1444941496
# 80 1444942696
# 100 1444943896

# %%
ROOTDIR="/mnt/ebola/ebov"
import os
os.environ['PATH'] = os.getenv('PATH') + ':' + ROOTDIR + '/scripts'

# %%
# %cd $ROOTDIR
# Out:
# [Errno 2] No such file or directory: '$ROOTDIR/180genomes-validation'
# /mnt/ebola/ebov/ipynb

# %%
# %cd ../180genomes-validation
# Out:
# /mnt/ebola/ebov/180genomes-validation

# %%
# %%bash
#
# ROOTDIR="/mnt/ebola/ebov"
# cd $ROOTDIR
# export PATH=`pwd`/bin/bwa:$PATH
# export PATH=$PATH:`pwd`/scripts
# export PATH=$PATH:`pwd`/bin/nanopolish-6mer
# export PATH=$PATH:`pwd`/bin/samtools
# export PATH=$PATH:`pwd`/bin/marginAlign
#
# mkdir -p 180genomes-validation
# cd 180genomes-validation
#
# echo "../models/6mer/ont_complement.pop1.model" > offset_models.fofn
# echo "../models/6mer/ont_complement.pop2.model" >> offset_models.fofn
# echo "../models/6mer/ont_template.model" >> offset_models.fofn
#
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 5 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 10 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 15 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 30 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 45 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 60 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 90 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 120 &
# #align_defaultkmer_margin_times.sh EM_079517 076533_180Genomes_11rx 076533_180Genomes_11rx 076533_180Genomes_11rx_hq na hq 1444937896 75 &
#
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 60 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 120 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 130 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 140 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 150 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 160 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 170 &
# align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 2 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 180 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 4 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 5 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 6 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 7 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 8 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 9 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 10 &
#
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 10 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 15 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 30 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 45 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 60 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 75 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 90 &
# #align_defaultkmer_margin_times.sh EM_079517 076769_180Genomes_19Rx 076769_180Genomes_19Rx 076769_180Genomes_19Rx_hq na hq 1444924205 120 &
# Out:
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# reading ../models/6mer/ont_template.model
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# reading ../models/6mer/ont_template.model
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# reading ../models/6mer/ont_template.model
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# reading ../models/6mer/ont_template.model
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# reading ../models/6mer/ont_template.model
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# reading ../models/6mer/ont_template.model
# reading ../models/6mer/ont_complement.pop1.model
# reading ../models/6mer/ont_complement.pop2.model
# ...

# %%
# !../scripts/vcfextract.py 076769_180Genomes_19Rx_hq1 076769_180Genomes_19Rx_hq2 076769_180Genomes_19Rx_hq3 076769_180Genomes_19Rx_hq4 076769_180Genomes_19Rx_hq5 076769_180Genomes_19Rx_hq6 076769_180Genomes_19Rx_hq7 076769_180Genomes_19Rx_hq8 076769_180Genomes_19Rx_hq9 076769_180Genomes_19Rx_hq10 076769_180Genomes_19Rx_hq130s 076769_180Genomes_19Rx_hq140s 076769_180Genomes_19Rx_hq150s 076769_180Genomes_19Rx_hq160s 076769_180Genomes_19Rx_hq170s > 076769.stats.txt
# Out:
# EM_079517_076769_180Genomes_19Rx_hq1_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq2_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq3_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq4_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq5_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq6_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq7_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq8_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq9_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq10_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq130s_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq140s_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq150s_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq160s_marginalign.sorted.bam
# EM_079517_076769_180Genomes_19Rx_hq170s_marginalign.sorted.bam

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# dat=read.table("076533.stats.txt", header=F, sep="\t")
# ggplot(dat, aes(x=V2, y=V3, color=factor(V1))) + geom_line() + ylim(0,400) + xlim(0,1000)
# Out:
# Error in read.table("076533.stats.txt", header = F, sep = "\t") :
#   no lines available in input
# /mnt/ebola/ebov/venv/local/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Error in read.table("076533.stats.txt", header = F, sep = "\t") :
#   no lines available in input
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /mnt/ebola/ebov/venv/local/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 1: Removed 1 rows containing missing values (geom_path).
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /mnt/ebola/ebov/venv/local/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 2: Removed 1 rows containing missing values (geom_path).
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /mnt/ebola/ebov/venv/local/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 3: Removed 1 rows containing missing values (geom_path).
#
# ...

# %%
# %%R
# library(ggplot2)
# dat=read.table("076769.stats.txt", header=F, sep="\t")
# ggplot(dat, aes(y=V2, x=V3, color=factor(V1))) +
#    geom_line() +
#    xlim(0,100) +
#    ylim(0,1000) +
#    xlab("Coverage (2D)") +
#    ylab("Log likelihood ratio") +
#    geom_vline(x=25) +
#    geom_hline(y=200) +
#    scale_color_discrete("SNP position") +
#    geom_text(aes(label="Masked positions", x=20, y=0), color="black") +
#    theme_bw()

# %%
## After the raw files are produced, show statistics.

# %cd 180genomes-validation
# Out:
# /mnt/ebola/ebov/180genomes-validation

# %%
fh = open("validation_files.txt", "w")
fh.write("""076534_180Genomes_11rx	np-var6mer-aln5mer	../refs/EM_079517_EM_076534.mutations.txt	np_EM_079517_076534_180Genomes_11rx_hq.vcf
076533_180Genomes_11rx	np-var6mer-aln5mer	../refs/EM_079517_EM_076533.mutations.txt	np_EM_079517_076533_180Genomes_11rx_hq.vcf
076383_180Genomes_11rx	np-var6mer-aln5mer	../refs/EM_079517_EM_076383.mutations.txt	np_EM_079517_076383_180Genomes_11rx_hq.vcf
078416_180Genomes_11rx	np-var6mer-aln5mer	../refs/EM_079517_EM_078416.mutations.txt	np_EM_079517_078416_180Genomes_11rx_hq.vcf
076769_180Genomes_19Rx	np-var6mer-aln5mer	../refs/EM_079517_EM_076769.mutations.txt	np_EM_079517_076769_180Genomes_19Rx_hq.vcf
""")
fh.close()

# %%
# !../scripts/intersection_vcf_stats.py validation_files.txt | cut -f 1,2,5,6,7,8,9,10 | column -t
# Out:
# sample                  tag                 total_calls  mutations  TP    FP   FN   TPR
# 076534_180Genomes_11rx  np-var6mer-aln5mer  14           18         14.0  0.0  4.0  0.777777777778
# 076533_180Genomes_11rx  np-var6mer-aln5mer  20           20         19.0  1.0  1.0  0.95
# 076383_180Genomes_11rx  np-var6mer-aln5mer  17           18         16.0  1.0  2.0  0.888888888889
# 078416_180Genomes_11rx  np-var6mer-aln5mer  18           18         17.0  1.0  1.0  0.944444444444
# 076769_180Genomes_19Rx  np-var6mer-aln5mer  19           19         19.0  0.0  0.0  1.0

# %%
# !../scripts/intersection_vcf_interrogate.py validation_files.txt > validation_stats.txt

# %%
# !head -10 validation_stats.txt
# Out:
# tag	pos	basecalledfreq	supportfraction	supportingreads	qual	state
# np-var6mer-aln5mer	213	0.748166	0.911469	906	4797.7	Real
# np-var6mer-aln5mer	800	0.895735	0.929348	513	3189.4	Real
# np-var6mer-aln5mer	1849	0.684444	0.73503	491	3453.2	Real
# np-var6mer-aln5mer	2124	0.847645	0.892068	686	5673.5	Real
# np-var6mer-aln5mer	6283	0.730769	0.9375	60	296.7	Real
# np-var6mer-aln5mer	6909	0.882812	0.952555	261	2143.7	Real
# np-var6mer-aln5mer	8928	0.647059	0.875587	373	1413.6	Real
# np-var6mer-aln5mer	11204	0.846405	0.941456	595	4667.5	Real
# np-var6mer-aln5mer	12208	0.874074	0.865152	571	4013.5	Real

# %%
# %load_ext rpy2.ipython
# Out:
# /mnt/ebola/ebov/venv/local/lib/python2.7/site-packages/rpy2/ipython/rmagic.py:68: UserWarning: The Python package 'pandas' is stronglyrecommended when using `rpy2.ipython`. Unfortunately it could not be loaded, but at least we found 'numpy'.
#   "but at least we found 'numpy'.")))

# %%
# %%R
#
# library(ggplot2)
#
# stats=read.table("validation_stats.txt", header=T)
# ggplot(stats, aes(x=supportfraction, fill=state)) + geom_histogram() + facet_wrap(~tag)
# Out:
# /mnt/ebola/ebov/venv/local/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %% [markdown]
# ## Remove low depth positions from plot (depth >= 30)

# %%
# %%R
#
# library(ggplot2)
#
# stats=read.table("validation_stats.txt", header=T)
# ggplot(subset(stats, supportingreads>50), aes(x=supportfraction, fill=state)) + geom_histogram(breaks=c()) + facet_wrap(~tag)

# %%
# %%R
#
# library(ggplot2)
#
# stats=read.table("validation_stats.txt", header=T)
# ggplot(subset(stats, supportingreads>50), aes(x=qual, fill=state)) + geom_histogram(breaks=c()) + xlim(0,2000) + facet_wrap(~tag)

# %% [markdown]
# ## Filter the files as per the study (depth > 30, support fraction > 0.70%, primer sequences masked)

# %%
# !makecommands.py ../metadata/metadata.db 180_Genomes consensus | parallel -j16
# Out:
# + ref_prefix=EM_079517
# + sample=076534_180Genomes_11rx
# + poretools_dir=076534_180Genomes_11rx
# + sample_tag=076534_180Genomes_11rx_hq
# + second_batch=na
# + vcftagprimersites.py all np_EM_079517_076534_180Genomes_11rx_hq.vcf
# + vcffilter.py 076534_180Genomes_11rx_hq_EM_079517_np_primer.tagged.vcf
# Output 14 records
# + vcffilterqual.py 076534_180Genomes_11rx_hq_EM_079517_np_primer.tagged.vcf
# Output 14 records
# + ref_prefix=EM_079517
# + sample=076383_180Genomes_11rx
# + poretools_dir=076383_180Genomes_11rx
# + sample_tag=076383_180Genomes_11rx_hq
# + second_batch=na
# + vcftagprimersites.py all np_EM_079517_076383_180Genomes_11rx_hq.vcf
# + vcffilter.py 076383_180Genomes_11rx_hq_EM_079517_np_primer.tagged.vcf
# Filtering Record(CHROM=EM_079517, POS=40, REF=G, ALT=[T])
# Output 16 records
# + vcffilterqual.py 076383_180Genomes_11rx_hq_EM_079517_np_primer.tagged.vcf
# Filtering Record(CHROM=EM_079517, POS=40, REF=G, ALT=[T])
# Output 16 records
# + ref_prefix=EM_079517
# ...

# %%
fh = open("validation_files_filtered.txt", "w")
fh.write("""076534_180Genomes_11rx	np-6mer-5meralign	../refs/EM_079517_EM_076534.mutations.txt	076534_180Genomes_11rx_hq_EM_079517_np_primer.filtered075_30.vcf
076533_180Genomes_11rx	np-6mer-5meralign	../refs/EM_079517_EM_076533.mutations.txt	076533_180Genomes_11rx_hq_EM_079517_np_primer.filtered075_30.vcf
076383_180Genomes_11rx	np-6mer-5meralign	../refs/EM_079517_EM_076383.mutations.txt	076383_180Genomes_11rx_hq_EM_079517_np_primer.filtered075_30.vcf
078416_180Genomes_11rx	np-6mer-5meralign	../refs/EM_079517_EM_078416.mutations.txt	078416_180Genomes_11rx_hq_EM_079517_np_primer.filtered075_30.vcf
076769_180Genomes_19Rx	np-6mer-5meralign	../refs/EM_079517_EM_076769.mutations.txt	076769_180Genomes_19Rx_hq_EM_079517_np_primer.filtered075_30.vcf""")
fh.close()

# %%
# !../scripts/intersection_vcf_stats.py validation_files_filtered.txt | cut -f 1,2,5,6,7,8,9,10 | column -t
# Out:
# sample                  tag                total_calls  mutations  TP    FP   FN   TPR
# 076534_180Genomes_11rx  np-6mer-5meralign  14           17         14.0  0.0  3.0  0.823529411765
# 076533_180Genomes_11rx  np-6mer-5meralign  19           19         19.0  0.0  0.0  1.0
# 076383_180Genomes_11rx  np-6mer-5meralign  16           17         16.0  0.0  1.0  0.941176470588
# 078416_180Genomes_11rx  np-6mer-5meralign  17           18         17.0  0.0  1.0  0.944444444444
# 076769_180Genomes_19Rx  np-6mer-5meralign  18           19         18.0  0.0  1.0  0.947368421053

# %% [markdown]
# # Get the 180 genome set

# %%
from Bio import Entrez
Entrez.email = "n.j.loman@bham.ac.uk"     # Always tell NCBI who you are
handle = Entrez.esearch(db="nucleotide", term="carroll and hiscox and ebola", retmax=200)
record = Entrez.read(handle)
handle = Entrez.efetch(db="nucleotide", id=record["IdList"], rettype="fasta", retmode="text")
fh = open("180_Genomes_references.fasta", "w")
fh.write(handle.read())

# %%
# !echo "\n"  >> 180_Genomes_references.fasta 
# !cat 180_Genomes_references.fasta  180_Genomes.fasta > validate_tree.fasta
# !sed --in-place '/^$/d' validate_tree.fasta
# !muscle3.8.31_i86linux64 -in validate_tree.fasta > validate_tree_aligned.fasta

# %%
# !sed --in-place 's/>.*H.sapiens-wt\//>/' validate_tree_aligned.fasta
# !sed --in-place 's/>EM_079517_/>MinION_/' validate_tree_aligned.fasta
# !sed --in-place 's/,//' validate_tree_aligned.fasta

# %%
# !grep ">" validate_tree_aligned.fasta

# %%
# !rm *validate_tree_aligned.raxml
# !raxmlHPC-PTHREADS-SSE3 -T 32 -f a -x 12345 -p 12345 -# 100 -m GTRGAMMA -s validate_tree_aligned.fasta -n validate_tree_aligned.raxml

# %%
# !cat /mnt/ebola/ebov/analysis/RAxML_bipartitions.validate_tree_aligned.raxml

# %%
# !pip install ete2

from ete2 import Tree
t = Tree()
t.populate(20)
t.render(file_name="test.png", w=500)
